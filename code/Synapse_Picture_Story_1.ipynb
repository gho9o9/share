# %% [markdown]
# # Azureポータル Azure Synapse Analytics リソース
#
# ## Synapse Studio へのリンク
# <img src="https://raw.githubusercontent.com/gho9o9/share/main/media/image/Synapse_Picture_Story_0.9.png"/>
#
# # 統合コンソール Synapse Studio
#
# # 「Home」タブ
#
# ## Synapse への入り口
# <img src="https://raw.githubusercontent.com/gho9o9/share/main/media/image/Synapse_Picture_Story_1.png" width="50%"/>
#
# # 「データ」タブ
#
# ## Synapseに統合された各種データベースのエクスプローラー
# <img src="https://raw.githubusercontent.com/gho9o9/share/main/media/image/Synapse_Picture_Story_1.9.png" width="50%"/>
#
# ### Dedicated SQL Pool
# <img src="https://raw.githubusercontent.com/gho9o9/share/main/media/image/Synapse_Picture_Story_2.png" width="50%"/>
#
# #### RDBのテーブルを簡単にSprakデータフレームに展開可能
# <img src="https://raw.githubusercontent.com/gho9o9/share/main/media/image/Synapse_Picture_Story_2.1.png" width="50%"/>
#
# ### Serverless SQL Pool
# <img src="https://raw.githubusercontent.com/gho9o9/share/main/media/image/Synapse_Picture_Story_3.png" width="50%"/>
#
# ### Serverless SQL Pool クエリエンジン によるデータレイクの直接参照も容易（仮想的な外部テーブルを定義することでファイルパスを隠蔽することで通常のRDB相当の使い勝手となる）
# <img src="https://raw.githubusercontent.com/gho9o9/share/main/media/image/Synapse_Picture_Story_3.1.png" width="50%"/>
#
# ### Spark Pool
# <img src="https://raw.githubusercontent.com/gho9o9/share/main/media/image/Synapse_Picture_Story_3.8.png" width="50%"/>
#
# ### Sparkテーブルの実体はデータレイク上のParquetファイルであるため Serverless SQL Pool クエリエンジン によりSQL文でSprakテーブルにアクセスすることも可能
# <img src="https://raw.githubusercontent.com/gho9o9/share/main/media/image/Synapse_Picture_Story_3.9.png" width="50%"/>
#
# ### Sparkテーブルのデータセットに対する自動機械学習もノーコードで開発可能
# <img src="https://raw.githubusercontent.com/gho9o9/share/main/media/image/Synapse_Picture_Story_4.png" width="50%"/>
# <img src="https://raw.githubusercontent.com/gho9o9/share/main/media/image/Synapse_Picture_Story_4.1.png" width="50%"/>
#
# ### Data Explorer Pool
# <img src="https://raw.githubusercontent.com/gho9o9/share/main/media/image/Synapse_Picture_Story_5.png" width="50%"/>
#
# ### Data ExplorerクエリエンジンによりテレメトリーデータへKustoによるクエリが可能
# <img src="https://raw.githubusercontent.com/gho9o9/share/main/media/image/Synapse_Picture_Story_5.1.png" width="50%"/>
#
# ### テレメトリーデータをSparkデータフレーム化したり、Sparkデータフレームをテレメトリーデータとして書き出すことも容易
# <img src="https://raw.githubusercontent.com/gho9o9/share/main/media/image/Synapse_Picture_Story_5.3.png" width="50%"/>
#
# ## Synapseにリンクされた外部ストアのエクスプローラー
#
# ### Data Lake Storage
# <img src="https://raw.githubusercontent.com/gho9o9/share/main/media/image/Synapse_Picture_Story_6.png" width="50%"/>
#
# ### Serverless SQL Pool クエリエンジン によるデータレイクの直接参照も容易（仮想的な外部テーブルを定義することでファイルパスを隠蔽することで通常のRDB相当の使い勝手を実現することも可能）
# <img src="https://raw.githubusercontent.com/gho9o9/share/main/media/image/Synapse_Picture_Story_6.1.png" width="50%"/>
#
# # 「開発」タブ
#
# ## Synapseに統合された各種クエリエンジンコードのエクスプローラー
# <img src="https://raw.githubusercontent.com/gho9o9/share/main/media/image/Synapse_Picture_Story_6.9.png" width="50%"/>
#
# ### Dedicated SQL Pool（腹持ちしたリレーショナルデータベースに対するSQL実行）
# <img src="https://raw.githubusercontent.com/gho9o9/share/main/media/image/Synapse_Picture_Story_7.png" width="50%"/>
#
# ### Serverless SQL Pool（データレイク上のデータファイルに対するSQL実行）
# <img src="https://raw.githubusercontent.com/gho9o9/share/main/media/image/Synapse_Picture_Story_8.png" width="50%"/>
#
# ### Spark Pool（ノートブックによるコードファーストでSprak処理を実装）
# <img src="https://raw.githubusercontent.com/gho9o9/share/main/media/image/Synapse_Picture_Story_9.png" width="50%"/>
#
# ### Data Flow（GUIによるノーコードでSpar処理を実装可能）
# <img src="https://raw.githubusercontent.com/gho9o9/share/main/media/image/Synapse_Picture_Story_6.9.1.png" width="50%"/>
#
# ### Data Explorer Pool（腹持ちしたKustoデータベースに対するKusto実行）
# <img src="https://raw.githubusercontent.com/gho9o9/share/main/media/image/Synapse_Picture_Story_10.png" width="50%"/>
#
# ### Power BI
# <img src="https://raw.githubusercontent.com/gho9o9/share/main/media/image/Synapse_Picture_Story_11.png" width="50%"/>
#
# ### Power BI（インタラクティブな可視化）
# <img src="https://raw.githubusercontent.com/gho9o9/share/main/media/image/Synapse_Picture_Story_12.png" width="50%"/>
#
# ### Power BI（異常検出：機械学習による予測値と連結した可視化）
# <img src="https://raw.githubusercontent.com/gho9o9/share/main/media/image/Synapse_Picture_Story_13.png" width="50%"/>
#
# ### Power BI（Kusto DBの可視化）
# <img src="https://raw.githubusercontent.com/gho9o9/share/main/media/image/Synapse_Picture_Story_14.png" width="50%"/>
#
# # 「統合」タブ
#
# ## Synapse Pipeline の実装
# <img src="https://raw.githubusercontent.com/gho9o9/share/main/media/image/Synapse_Picture_Story_15.png" width="50%"/>
#
# # 「監視」タブ
#
# ## Synapseに統合された各種クエリエンジンのリソース使用状況
# <img src="https://raw.githubusercontent.com/gho9o9/share/main/media/image/Synapse_Picture_Story_16.png" width="50%"/>
#
# ## クエリエンジンへのリクエスト
# <img src="https://raw.githubusercontent.com/gho9o9/share/main/media/image/Synapse_Picture_Story_17.png" width="50%"/>
# <img src="https://raw.githubusercontent.com/gho9o9/share/main/media/image/Synapse_Picture_Story_18.png" width="50%"/>
#
# ## Synapse Pipeline ジョブのステータス
# <img src="https://raw.githubusercontent.com/gho9o9/share/main/media/image/Synapse_Picture_Story_19.png" width="50%"/>
#
# # 「管理」タブ
#
# ## Synapseに統合された各種クエリエンジンの管理（起動停止 や コンピューティングリソースPoolの追加削除）
# <img src="https://raw.githubusercontent.com/gho9o9/share/main/media/image/Synapse_Picture_Story_20.png" width="50%"/>
# <img src="https://raw.githubusercontent.com/gho9o9/share/main/media/image/Synapse_Picture_Story_21.png" width="50%"/>
#
# ## Synapseにリンクするサービスの管理（追加削除）
# <img src="https://raw.githubusercontent.com/gho9o9/share/main/media/image/Synapse_Picture_Story_22.png" width="50%"/>
#
# ## Synapse Pipeline のコンピュートリソースの管理（追加削除 や コンピューティングパワーの定義）
# <img src="https://raw.githubusercontent.com/gho9o9/share/main/media/image/Synapse_Picture_Story_23.png" width="50%"/>
#
# ## Synapse Studio ユーザの管理
# <img src="https://raw.githubusercontent.com/gho9o9/share/main/media/image/Synapse_Picture_Story_24.png" width="50%"/>
#
# ## クエリエンジンコードのGit管理のための構成定義
# <img src="https://raw.githubusercontent.com/gho9o9/share/main/media/image/Synapse_Picture_Story_25.png" width="50%"/>
#
# # 「Home」タブ
#
# ## 各種関連情報へのポータル
# <img src="https://raw.githubusercontent.com/gho9o9/share/main/media/image/Synapse_Picture_Story_26.png" width="50%"/>
#
# ## ギャラリー：サンプルデータやオープンデータ、サンプルコードを公開
# <img src="https://raw.githubusercontent.com/gho9o9/share/main/media/image/Synapse_Picture_Story_27.png" width="50%"/>
# <img src="https://raw.githubusercontent.com/gho9o9/share/main/media/image/Synapse_Picture_Story_28.png" width="50%"/>
#
# ## ギャラリー：業界特化のDBスキーマ定義テンプレート や 該当スキーマ定義を前提とした典型的な分析モデル を公開
# <img src="https://raw.githubusercontent.com/gho9o9/share/main/media/image/Synapse_Picture_Story_29.png" width="50%"/>
# <img src="https://raw.githubusercontent.com/gho9o9/share/main/media/image/Synapse_Picture_Story_30.png" width="50%"/>
# <img src="https://raw.githubusercontent.com/gho9o9/share/main/media/image/Synapse_Picture_Story_31.png" width="50%"/>
